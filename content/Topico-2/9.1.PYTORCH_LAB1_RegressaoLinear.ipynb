# %% [markdown]
# # [LAB1] Tutorial PyTorch:
#
#     1) Regressão Linear

# %% [markdown]
# ## Importação de Bibliotecas

# %% [markdown]
# ### Objetivo
#
# Neste notebook, você irá aprender a utilizar o PyTorch para resolver problemas de **regressão linear**. Ao final, será capaz de construir modelos simples e interpretar seus resultados.

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ## Parte 1 – Regressão Linear (y = 2x + 1)

# %%
# Dados sintéticos
x = torch.unsqueeze(torch.linspace(-5, 5, 101), dim=1)
y = 2 * x + 1 + 0.9 * torch.randn(x.size())

# Visualização
plt.scatter(x.numpy(), y.numpy())
plt.title("Dados de Regressão Linear")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# Modelo linear
class ModeloRegressao(nn.Module):
    def __init__(self):
        super(ModeloRegressao, self).__init__()
        self.linear = nn.Linear(1, 1)
    def forward(self, x):
        return self.linear(x)

# %%
modelo = ModeloRegressao()
criterio = nn.MSELoss()
otimizador = torch.optim.SGD(modelo.parameters(), lr=0.001)

# Treinamento
for epoca in range(500):
    saida = modelo(x)
    perda = criterio(saida, y)

    otimizador.zero_grad()
    perda.backward()
    otimizador.step()

    if (epoca + 1) % 10 == 0:
        print(f'Época {epoca+1}, Perda: {perda.item():.4f}')
# Out:
# Época 10, Perda: 48.6143
# Época 20, Perda: 35.4693
# Época 30, Perda: 26.1109
# Época 40, Perda: 19.4408
# Época 50, Perda: 14.6799
# Época 60, Perda: 11.2748
# Época 70, Perda: 8.8331
# Época 80, Perda: 7.0761
# Época 90, Perda: 5.8059
# Época 100, Perda: 4.8821
# Época 110, Perda: 4.2050
# Época 120, Perda: 3.7039
# Época 130, Perda: 3.3285
# Época 140, Perda: 3.0430
# Época 150, Perda: 2.8221
# Época 160, Perda: 2.6478
# Época 170, Perda: 2.5072
# Época 180, Perda: 2.3912
# Época 190, Perda: 2.2933
# Época 200, Perda: 2.2089
# Época 210, Perda: 2.1346
# Época 220, Perda: 2.0680
# Época 230, Perda: 2.0076
# Época 240, Perda: 1.9519
# Época 250, Perda: 1.9001
# Época 260, Perda: 1.8516
# Época 270, Perda: 1.8059
# Época 280, Perda: 1.7626
# Época 290, Perda: 1.7214
# Época 300, Perda: 1.6821
# Época 310, Perda: 1.6446
# Época 320, Perda: 1.6088
# Época 330, Perda: 1.5744
# Época 340, Perda: 1.5415
# Época 350, Perda: 1.5100
# Época 360, Perda: 1.4797
# Época 370, Perda: 1.4506
# Época 380, Perda: 1.4227
# Época 390, Perda: 1.3959
# Época 400, Perda: 1.3702
# Época 410, Perda: 1.3454
# Época 420, Perda: 1.3217
# Época 430, Perda: 1.2989
# Época 440, Perda: 1.2770
# Época 450, Perda: 1.2559
# Época 460, Perda: 1.2357
# Época 470, Perda: 1.2163
# Época 480, Perda: 1.1976
# Época 490, Perda: 1.1797
# Época 500, Perda: 1.1625

# %% [markdown]
# ### Exercício 1
#
# Modifique a taxa de aprendizado (`lr`) para `0.001`, `0.01` e `0.1`. Observe como isso afeta a convergência do modelo. Qual taxa parece melhor neste caso?

# %%
# Visualização dos resultados
plt.scatter(x.numpy(), y.numpy(), label='Dados reais')
plt.plot(x.numpy(), modelo(x).detach().numpy(), color='red', label='Predição')
plt.legend()
plt.title("Regressão Linear com PyTorch")
plt.show()

# %% [markdown]
# ## Parte 2 – Regressão Não Linear (y = 3x² - 10x + 6)
#
# OBS: NÃO É PARA FAZER, APENAS GERAR A REFLEXÃO, ESTE SERÁ FEITO NO LAB2.

# %% [markdown]
# ### Exercício 2
#
# a) Sugira quais modificações deverão ser feitas na função hipótese do modelo anterior para (y = 3x² - 10x + 6).
#
# b) você acha que o modelo de redes neural anterior consegue se ajustar ou ocorre algum problema?

# %%
# Dados quadráticos
x = torch.unsqueeze(torch.linspace(-2, 5, 200), dim=1)
y = 3 * x**2 - 10 * x + 6 + 1.0 * torch.randn(x.size())

plt.scatter(x.numpy(), y.numpy(), s=10)
plt.title("Função alvo: y = 3x² - 10x + 6")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
